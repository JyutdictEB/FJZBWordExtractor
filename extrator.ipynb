# %%
import typing
import re

wordWild = r"[~～]"

def loadRawCSV(path : str):
  ret = []
  with open(path,encoding='utf-8',mode='r') as raw_file:
    for line in raw_file.readlines():
      ret.append(line.strip().split(","))
  return ret

def containWordWild(input : str):
  return re.search(wordWild,input) is not None
  
def locateWordLine(lines: typing.List[str]):
  ret = []
  for line in lines:
    dsc = line[2]
    if containWordWild(dsc):
      ret.append(line)
  return ret
  
def posWordInLine(line:str):
  return list(res.start() for res in re.finditer(wordWild,line))

# 先 define 啲 helper，然後寫一個提詞方法
def isCJK(char : str):
  utfcode = ord(char.encode("utf-8").decode())
  cpr = []
  # regular
  cpr.append((0x4E00,0x9FFF))
  # ExtA
  cpr.append((0x3400,0x4DBF))
  # ExtB
  cpr.append((0x20000,0x2A6DF))
  # ExtC
  cpr.append((0x2A700,0x2B73F))
  # ExtD
  cpr.append((0x2B740,0x2B81F))
  # ExtE
  cpr.append((0x2B820,0x2CEAF))
  # ExtF
  cpr.append((0x2CEB0,0x2EBEF))
  # ExtG
  cpr.append((0x30000,0x3134F))
  return any(cmp[0] <= utfcode <= cmp[1] for cmp in cpr)

# 寫切詞方法
def splitWord(line:str):
  def traverseUntilNotCJK(line:str,start_pos :int,direction : int, len_limit = 3):
    cur_pos = start_pos
    should_skip = lambda char : not containWordWild(char) and not isCJK(char)
    for i in (range(start_pos,len(line),1) if direction > 0 else range(start_pos,0,-1)):
      char = line[i]
      if(len_limit == 0):
        break
      len_limit -= 1  
      cur_pos = i
      if should_skip(char):
        cur_pos += 1
        break

    return cur_pos
  
  ret = []
  if(type(line) != str):
    return ret
  pos = posWordInLine(line)
  for eachPos in pos:
    left_bound = right_bound = eachPos
    left_bound = traverseUntilNotCJK(line,left_bound,-1)
    right_bound = traverseUntilNotCJK(line,right_bound,1)
    word = line[left_bound:right_bound]
    ret.append(word)
  return ret

# %% [markdown]
# 试下 识別效果

# %%
print(isCJK("a"))
print(isCJK("（"))
print(isCJK("一"))
print(isCJK("|"))
print(isCJK("｜"))
print(isCJK("𡠀"))
print(isCJK("ㄦ"))
# Out:
# False
# False
# True
# False
# False
# True
# False

# %% [markdown]
# 開始 試下 揾詞

# %%
raw_data = loadRawCSV("faanjyutExport.csv")
ele_with_words = locateWordLine(raw_data)
words = []
for ele in ele_with_words:
  line = ele[2]
  single_char = ele[0]
  pron = ele[1]
  words_in_line = splitWord(line)
  if(len(words_in_line) == 0):
    continue
  print(words_in_line)
  words.append(words_in_line)
# Out:
# ['～粉）']
# ['面～｜', '面珠']
# ['缸～｜', '～缸｜', '缸～']
# ['～場｜', '大～場(']
# ['慳～）']
# ['思～）']
# ['百～）']
# ['重～', '重～']
# ['邊～？', '南～。']
# ['黑～～）', '黑～～）']
# ['腍～～｜', '腍～～｜', '溶～～｜', '溶～～｜', '腍～劣｜', '溶～膉。']
# ['～一']
# ['係有～。']
# ['～悠）']
# ['～悠）']
# ['～h']
# ['淡～～｜', '淡～～｜', '淡～劣(']
# ['～脷）', '真係～囉。']
# ['斬～蔗']
# ['正～）', '正～白']
# ['正～）', '正～白']
# ['正～）', '正～白']
# ['老～｜', '老～仔｜', '老～妹。']
# ['～～', '～～聲']
# ['你都～嘅｜', '知傻～～', '傻～～冇']
# ['冤～）']
# ['～身', '～轉', '拗～條']
# ['～擬）', '冇使～佢']
# ['指～）', '冇使～佢']
# ['～開']
# ['水～｜', '替死～；', '～佬｜', '～妹；', '麻～煩｜', '～咁', '咁～死', '窮～｜', '衰～。']
# ['～你']
# ['～～）', '～～）', '～～', '～～仔）']
# ['～周｜', '～㞗｜', '有冇～㗎？']
# ['賓～｜', '賓～仔｜', '有冇～㗎？']
# ['水就～起', '電池～成']
# ['力啲～先']
# ['一～鎖', '一～']
# ['～糟）']
# ['屙～屎；', '粥好～。']
# ['魚～）']
# ['起～｜', '蚊～｜', '起䊆～。']
# ['～亂）', '～～', '～～亂）']
# ['口～）', '口～～）', '口～～）']
# ['黑～～）', '黑～～）']
# ['～開。']
# ['～刺）']
# ['～糖', '～住']
# ['等我～下']
# ['條船～埋；', '～檔；', '～拖）']
# ['呢～我']
# ['～懵｜', '～一', '～一～，']
# ['日手～腳', '～腳～。']
# ['成～']
# ['～～）', '～～）', '脹～～）', '脹～～）']
# ['魚~）']
# ['～蓋）']
# ['槍打～嘹，']
# ['～']
# ['人都～齊｜', '～下', '～下～下(']
# ['人咁～，']
# ['咁～等']
# ['～鏡）']
# ['～開', '後便～矣']
# ['食～好']
# ['架～）', '攞啲～過']
# ['噉呅～。']
# ['～']
# ['柑好～。']
# ['～乾']
# ['～?']
# ['咁鬼～嘅。']
# ['～到']
# ['我冇～有']
# ['海']
# ['~地']
# ['頭極～。']
# ['間太～多。']
# ['肚~。']
# ['~~）', '~~）', '禾秧～～', '秧～～動。']
# ['心～）']
# ['～頸；']
# ['～埋']
# ['蓋扱～啲；', '閂～道', '得好～；', '隻緩～住']
# ['膍～｜', '腑～；', '腑～）', '咁多']
# ['仲～幾', '仲～佢', '～']
# ['～蛋）']
# ['～鬼）']
# ['～衣', '～起', '先～幾']
# ['冇釐～?']
# ['～開']
# ['漏～）']
# ['煲到～']
# ['條衫～開', '牙刷～矣。']
# ['鑊～｜', '沙煲']
# ['粥好～｜', '煮到～晒。']
# ['～塞）']
# ['～落']
# ['骨鷂～落', '樓頂～落｜', '～落']
# ['～雞', '門框～着']
# ['曬～皮。']
# ['～得']
# ['雨～）']
# ['～l']
# ['稀～～）', '稀～～）']
# ['～）']
# ['媽～）']
# ['～係', '～穩']
# ['～㗎）', '尾要～做？']
# ['～實', '時間～～', '間～～緊 ']
# ['～殼｜', '～開。']
# ['～水）']
# ['老～）']
# ['～頭）']
# ['鹹～～）', '鹹～～）']
# ['佢未～錢']
# ['講～ ']
# ['～酸）']
# ['～n']
# ['～）']
# ['鬼～）']
# ['頸～下']
# ['～n']
# ['隻蛤～入']
# ['～人(', '～生', '～人。']
# ['～仔）']
# ['～，']
# ['～仔）']
# ['～']
# ['～衣 ', '～鞋 ', '落～"']
# ['墨～）']
# ['～）']
# ['～m']
# ['石～）']
# ['發肉～）']
# ['～理）']
# ['～街｜', '～']
# ['老～）']
# ['一四～）']
# ['～嘢。']
# ['佢～單', '我冇～錯']
# ['～刀。']
# ['～算）']
# ['低']
# ['食～嚟']
# ['瞇～｜', '眼瞇～', '瞇～']
# ['瞇～瞇', '～瞇～）']
# ['咳～～ ', '咳～～ ']
# ['幾點～北', '唔好～支', '～髮(', '～冰(']
# ['唔好～，', '～人(', '～佬(', '～青(', '～糖(']
# ['～撈l', '～主）']
# ['～撈l']
# ['解咁～嘅？']
# ['菜～｜', '果～。']
# ['～精｜', '～瘋｜', '～懵。']
# ['～住']
# ['豬頭～）', '～）']
# ['滑～｜', '唔啱～(']
# ['合～）', '啱晒～(']
# ['～尺）', '啱晒～(']
# ['啱～）']
# ['啲唔～噃(']
# ['時好～㗎。']
# ['～人', '～晒']
# ['靜～～）', '靜～～）']
# ['靜～～）', '靜～～）']
# ['你爲～']
# ['哥～｜', '姐～(']
# ['櫃～）', '拖～）']
# ['～話）', '學咁～。']
# ['～）', '佢一']
# ['～錢 ', '佢～我']
# ['～臣）', '～筍）']
# ['你咁～嘅？', '度扮～喎。']
# ['落～(', '～糕｜', '～櫃(', '～起', '～肉｜', '～蛋。']
# ['青～～）', '青～～）', '塊面～嘅？']
# ['～子）', '～緻）', '都幾～喎；', '都幾～喎。']
# ['老～）']
# ['一～；', '睇～｜', '買～(']
# ['白～）']
# ['齊～～）', '齊～～）', '頭髮～。']
# ['～一', '～佢']
# ['～鉗）']
# ['凹～｜', '水～｜', '糞～；', '～渠｜', '羅～(']
# ['合～｜', '啱～｜', '過']
# ['濁～～）', '濁～～）']
# ['～b']
# ['～屋 ', '一樓～畀']
# ['屋～）']
# ['～）', '塵兼']
# ['～f', '塵兼']
# ['濕～～）', '濕～～）']
# ['位咁～嘅。']
# ['～']
# ['一～豬', '一～黑', '一～石']
# ['精～｜', '教～']
# ['眼～）']
# ['仔好']
# ['～路｜', '行～路。']
# ['～）']
# ['牛～t']
# ['祖公～）', '雞～(', '牛～"']
# ['講牙～｜', '口～', '口～']
# ['～香']
# ['～條', '～條']
# ['姨～(', '舅～(']
# ['～你。']
# ['上街～。']
# ['姿～）', '覅太～；']
# ['稀～～｜', '稀～～｜', '～～。', '～～。']
# ['～蟹(', '～蟹']
# ['海～）']
# ['手指～）', '要撳～。']
# ['～時）', '平～時）', '～佢', '～時）', '～未']
# ['沙～）', '識幾～。']
# ['～塵）', '識幾～c']
# ['箇幫～又', '～仔。']
# ['～了', '東～）']
# ['～鷹；', '紙～）']
# ['條繩～兩', '～兩～。']
# ['～你']
# ['光～～）', '光～～）', '仲光～～', '光～～咁。']
# ['芋～）']
# ['～衫|', '～皺|', '額頭～幾']
# ['大髀～）']
# ['～']
# ['沖～ ']
# ['～額']
# ['吊㢥～）', '成日～去。']
# ['吊～']
# ['飯店～到']
# ['～尿', '～豬', '處都～牛']
# ['～度(', '老人～(']
# ['公～|', '嬤～|', '死公～死', '死嬤～。']
# ['～算？', '～蚊(', '同～(']
# ['白～～）', '白～～）', '得白～～。', '白～～。']
# ['胳肋～）']
# ['越～）']
# ['～']
# ['趁～）']
# ['執～|', '棉～。']
# ['～）']
# ['酸～）', '菜酸～酸', '～酸～个。']
# ['～屎｜', '～']
# ['蝦～）', '蝦～笪）']
# ['～腳(', '～腳', '～心。']
# ['～粉|', '欶']
# ['～粉）']
# ['火～腸）']
# ['條～喊']
# ['摩～車）']
# ['碗～|', '皮鞋～｜', '隻碗～來']
# ['～子）', '～傾', '～喫']
# ['禾～）']
# ['眼～）', '幾眼～。']
# ['～葉(', '～(', '假～(']
# ['煙～～）', '煙～～）', '京煙～～', '煙～～去。']
# ['～仔｜', '佬哥～到']
# ['喃～(', '做']
# ['～婚）', '靚仔～。']
# ['阿～）']
# ['星～坡）', '新～坡）']
# ['～仔｜', '～']
# ['～南）']
# ['屌～㜷｜', '屌～奶｜', '屌～媽｜', '挑～']
# ['荷～｜', '～豆(']
# ['～風）']
# ['紅桃～(']
# ['～）']
# ['～k']
# ['～水｜', '～擔(', '～梯｜', '～凳；', '～遮；', '～起']
# ['～蓋|', '洗～|', '～㞘。']
# ['馬～）']
# ['～蕃', '薯好～(']
# ['搣～佢|', '～|', '～（']
# ['～～', '～～幡', '自己～住']
# ['～佢']
# ['～色｜', '～黑｜', '玫瑰～。']
# ['～灰｜', '～鐋｜', '～墙']
# ['肚～）', '佢～大']
# ['近～｜', '有']
# ['～佢', '順手～丟', '～炮(', '然間～落', '～條']
# ['～腸(']
# ['～蚍）']
# ['白～～。', '白～～。']
# ['你仲～出']
# ['眼～：']
# ['～嘴']
# ['路一～一', '～一～；', '條船～來', '～來～去。']
# ['～眼。']
# ['轉頭～後']
# ['成日～。']
# ['～']
# ['爆晒']
# ['～雞']
# ['㜷～｜', '～｜', '～～(', '～～(']
# ['淡～～）', '淡～～）']
# ['一炮～过', '～佢']
# ['行到～｜', '～頭｜', '～㞘。']
# ['～下']
# ['水']
# ['～一', '識幾～。']
# ['嬤～｜', '～嬤｜', '牀～嬤(', '月～～(', '月～～(', '～㜷']
# ['～口']
# ['东～西', '～西～｜', '～水(']
# ['鬧人～。']
# ['嗰～學', '邊～。']
# ['一～', '一～']
# ['出～｜', '田～。']
# ['趨前～後｜', '～車｜', '～軚(']
# ['一～垃']
# ['花梨～噶|', '都係～做，', '～字', '字噉～。']
# ['暈～～）', '暈～～）']
# ['～佢']
# ['茶杯～。']
# ['隨便～在']
# ['一～被。']
# ['你～住']
# ['～']
# ['眼～～｜', '眼～～｜', '時肯～我。']
# ['一～碌']
# ['～步；', '幾～腳']
# ['粥太～。']
# ['～乸｜', '～?']
# ['～茶｜', '菊花～水', '～熱', '～雞｜', '～番', '頭好～；', '～老']
# ['～腰。']
# ['～門│', '～頭│', '～腦']
# ['～來', '～來～去｜', '～～', '～～轉(']
# ['兩～水。']
# ['爛～｜', '蛤～｜', '～仔。']
# ['～打', '～來', '～來～去']
# ['～竹', '～竹～木。']
# ['～）']
# ['～?', '～出']
# ['我冇～；', '～']
# ['食多～肥；', '時佢～在', '江水～浸']
# ['屙～。']
# ['人哋']
# ['～有｜', '～係；', '～加。']
# ['發～。']
# ['趁～；', '～']
# ['螺丝～，', '牙']
# ['周身～。']
# ['殼好～；', '頭好～；', '～熱']
# ['～呦）']
# ['咿~）', '咿~。']
# ['～雜）', '咁多～嘢。']
# ['寬～～｜', '寬～～｜', '～䆲｜', '～䆡。']
# ['天～|', '燈咁～。']
# ['半～k']
# ['元']
# ['～東｜', '～埌']
# ['睇～眼。']
# ['成日～你']
# ['姐極～行']
# ['一～柑']
# ['～）']
# ['坡夠～；', '上～；', '一咀～咁']
# ['出去～；', '～游', '好好～。']
# ['擺好～。']
# ['車～｜', '四隻～；', '～隻']
# ['杧果～落；']
# ['識幾～；', '涫水～豬', '～麪', '～雞']
# ['～皮|', '～牙｜', '～骹(', '～色｜', '褲～～；', '褲～～；']
# ['～慣']
# ['圈～）']
# ['～衫', '～納']
# ['出來～。']
# ['～戚']
# ['～皮｜', '～筆；', '～落', '～書(', '～家(']
# ['～監(']
# ['～子｜', '～。']
# ['～']
# ['～花｜', '～橘']
# ['～殼）']
# ['溼～～｜', '溼～～｜', '～～', '～～']
# ['～嘴｜', '嘴～～|', '嘴～～|', '冩～字。']
# ['～']
# ['酸～草）', '酸～）']
# ['企咁～｜', '到咁～好', '～～）', '～～）', '～達']
# ['肉～～。', '肉～～。']
# ['把刀～嘹。']
# ['臭～；', '日夠～哦！']
# ['炙～；', '～着(']
# ['我～緊']
# ['～癟', '～善；', '得好～，']
# ['～本']
# ['～阿']
# ['細～；', '細～｜', '～絲。']
# ['～頭。']
# ['～沉）', '～～', '～～沉', '在啲～。']
# ['直個～，', '～到', '佢～咗']
# ['公極～肉。']
# ['～時', '～講(']
# ['～好', '講得～；', '～心', '家好～；', '電影～開']
# ['～來', '～來～去｜', '～']
# ['～']
# ['～墻', '～更｜', '～褦。']
# ['比較～噶；', '～對']
# ['～出']
# ['肥～。']
# ['～糯。']
# ['吊～～）', '吊～～）']
# ['仲～一', '～一～｜', '～?']
# ['條衫～～', '衫～～個｜', '～額']
# ['冇～得?']
# ['身～｜', '～?']
# ['甘蔗～；']
# ['仔咁～吶！']
# ['～實。']
# ['～屎｜', '～?']
# ['～來。', '～火']
# ['～到', '～網。']
# ['～口｜', '～口']
# ['豬']
# ['～得', '～喽']
# ['～佢']
# ['～日｜', '～輪', '一～?', '～冇']
# ['～鼻']
# ['～碎(']
# ['醒～）', '即刻～嘹。']
# ['～時', '～壞(', '搞～啲', '～哦。']
# ['騷～｜', '～蟲。']
# ['甴～）']
# ['～眼。']
# ['～水(']
# ['～仔。']
# ['冇～你']
# ['～旗，', '～尾。']
# ['～浮｜', '～良｜', '～石（']
# ['燈一～一', '～一～。']
# ['水～出', '隻桶～水；', '～下', '～花｜', '～田。']
# ['～']
# ['～褲']
# ['爛～；', '～畫']
# ['喺度～我；', '佢～我']
# ['～牛。']
# ['～豬｜', '～雞；', '～仔。']
# ['～米。']
# ['符～）']
# ['蚊～紙，', '毫～']
# ['妹至～就']
# ['冩～啲，', '痣幾～。']
# ['惡死～噋）']
# ['㷫～～）', '㷫～～）']
# ['腳好～，', '～曠']
# ['臭～；', '～官。']
# ['街上～是']
# ['真～！', '醬最～！']
# ['膿～）']
# ['～膎）']
# ['條魚～開|', '～開', '～成']
# ['～啲', '～啲']
# ['～直', '～']
# ['～日）']
# ['～度']
# ['我～佢', '～數；', '測～）', '～下', '測～）', '袋米～有', '～稱']
# ['你咁～嘅|', '～人|', '好～。']
# ['～筍）']
# ['有啲']
# ['～機|', '～大']
# ['～行']
# ['聽佢～；']
# ['要亂～。']
# ['有人～佢；', '～?']
# ['龐～）']
# ['喫～了。']
# ['捱車～到。']
# ['竹～；', '蔗～；', '菜～；', '豆～；', '指～）']
# ['～?']
# ['一～']
# ['一～']
# ['～豚）']
# ['鼻～）']
# ['你有～到']
# ['盤菜～嗎？']
# ['～）']
# ['嘢都～得', '～佢', '抽～）']
# ['～惜）']
# ['～牙', '～青']
# ['浸到～；', '～']
# ['～水）']
# ['～藥｜', '～手｜', '～腳；', '～花｜', '～']
# ['～味｜', '～臭；', '～㴙）', '～在']
# ['㳌～）']
# ['～骨）']
# ['起']
# ['～住｜', '～']
# ['～哇']
# ['去']
# ['～']
# ['呢～人']
# ['～沙）']
# ['～下']
# ['烏～～）', '烏～～）']
# ['畀人～嘅']
# ['～']
# ['～']
# ['細～仔）']
# ['～']
# ['臭火～。']
# ['大隻～', '隻～']
# ['眼～）']
# ['～汁）']
# ['～～', '～～震｜', '發～']
# ['～～', '～～']
# ['發吽～）']
# ['泥～）']
# ['～']
# ['～手']
# ['眼～', '眼～']
# ['指甲～澌']
# ['～～', '～～']
# ['臭～｜', '～崩']
# ['～雞｜', '～']
# ['踩到～；', '到咁']
# ['～～', '～～呱']
# ['～低。']
# ['～']
# ['～）']
# ['～g']
# ['苦喊']
# ['煎～）']
# ['～時']
# ['眼～～）', '眼～～）']
# ['吃～）']
# ['老～～）', '老～～）']
# ['～酒）']
# ['～']
# ['～酒）']
# ['蛋']
# ['～色；', '凍～｜', '奶～｜', '齋～｜', '淨']
# ['亞～）', '～阿）']
# ['～']
# ['得～，', '做～。']
# ['眼～～）', '眼～～）']
# ['～」', '可以～，', '睇得']
# ['～箇']
# ['打～。']
# ['～鷄｜', '吠就～咧']
# ['一～雀。']
# ['冇～得?']
# ['～古']
# ['～屋。']
# ['西瓜～甜。']
# ['～～）', '～～）', '屙～～）', '屙～～）']
# ['～尿。']
# ['供～。']
# ['做～｜', '～婆。']
# ['竹～）']
# ['記得～啲', '～出']
# ['～']
# ['有～，', '好']
# ['～我']
# ['猜～）']
# ['～肉；', '背～）']
# ['馱～女|', '生～']
# ['米～）']
# ['左手～）']
# ['豬～腮）']
# ['疤～）']
# ['扁鼻～～）', '鼻～～）']
# ['～仔|', '']
# ['～兒|', '～女；', '～']
# ['～坡）']
# ['熱～～）', '熱～～）']
# ['～']
# ['～']
# ['鐵～）']
# ['～就', '一～）', '～你']
# ['～坭？']
# ['哪～？', '～。']
# ['屄～']
# ['～隊(']
# ['～落']
# ['屋～']
# ['豬～']
# ['～衫']
# ['跌～跌', '～跌']
# ['～鑊']
# ['密密～～）', '密～～）']
# ['供～）']
# ['打～｜', '～頭(']
# ['把～。']
# ['～', '～']
# ['～']
# ['籮～。']
# ['田～；', '～埒。']
# ['～嘈）']
# ['～']
# ['～佢']
# ['眼～～。', '眼～～。']
# ['手～。']
# ['～肉）']
# ['～女']
# ['一張']
# ['噉～|', '點']
# ['～水）']
# ['～雞|', '～仔|', '～']
# ['水沖～了', '樹～了；', '～牙|', '碗～了。']
# ['～叔。']
# ['一隻～。']
# ['一隻～。']
# ['肚～）']
# ['一～油|', '一～皮。']
# ['忻住～親。', '下好～。']
# ['～睇。']
# ['餸都～在']
# ['地去～两']
# ['冇鹹～。']
# ['一毫～|', '一分～|', '散～。']
# ['凐～～）', '凐～～）']
# ['一～一', '～一～；', '跛～。']
# ['准劏～冇']
# ['十三～。']
# ['～妹', '～佢']
# ['好～啊|', '～閪；', '好～啊|', '～閪。']
# ['～隻', '～～', '～～埋', '一手～落']
# ['～酒）']
# ['歌好～。']
# ['差～）']
# ['呢啲～啱。']
# ['工好～㗎。']
# ['～掣|', '～芯']
# ['到～。']
# ['扇牆～咧，']
# ['就～張']
# ['杯水～？', '水去～？']
# ['打機～？']
# ['～惰，']
# ['你去～？', '好睇～？']
# ['個好～！']
# ['晒去']
# ['試下～？', '華去～？', '鐘頭～？']
# ['呃你～│', '唔好～！']
# ['飯香～？', '唔得～？']
# ['嚟齊～。']
# ['伯䎺～？', '走澌～？']
# ['落嚟～！']
# ['啲去～！', '好～，', '就點～！', '係噉～│', '乜講～！', '係你～，', '一家～，', '佢哋～，', '呢度～，']
# ['幾抵～？', '好喇～？']
# ['走喇～！', '搞嘅～？']
# ['小姐～？', '出嚟～？']
# ['～，']
# ['唔係～，']
# ['實嚟～？', '小姐～？', '大晒～？']
# ['唔去～？', '唔得～？', '想點～？']
# ['又得～；', '乜嘢～！', '志在～！']
# ['啱～；', '我明～！', '冇壞～！']
# ['嗚～！', '～！']
# ['變澌～！', '咁多～|', '唔䎺～。']
# ['死唨～；', '晒走']
# ['講下～，']
# ['頭好～眼。']
# ['同一～']
# ['你做～工']
# ['張牀～牆']
# ['～']
# ['冷就～多']
# ['～糯。']
# ['我～渠', '我～你']
# ['一～糕｜', '～']
# ['飯焦～住']
# ['翁～）']
# ['～波|', '一腳～過']
# ['～恁']
# ['畀佢～吖？']
# ['想去～睇']
# ['出']
# ['～日(']
# ['在～）']
# ['～g']
# ['搞扂～']
# ['～位｜', '閂～門；', '連～｜', '叫～渠', '～單；', '要做～作', '你睇～啲']
# ['～水｜', '速速～，']
# ['腳一～，']
# ['～/', '～）']
# ['身～｜', '肥～大']
# ['矮～）']
# ['腳～）']
# ['白～）']
# ['糖好～。']
# ['魚好～。']
# ['糖好～。']
# ['～皮）']
# ['～口）']
# ['拗～｜', '頑～（', '明～（', '束～（']
# ['白白～）']
# ['～善）']
# ['獅～功。']
# ['條狗～了', '獅～功。']
# ['街上～到']
# ['街上～到']
# ['灰～｜', '料～；', '托車～｜', '翻～']
# ['～入', '～好']
# ['～埋']
# ['上高～来', '～来～去；', '～下', '～下～下。']
# ['亂～｜', '～來', '～來～去｜', '亂～｜', '吊吊']
# ['～佢']
# ['唔好～咁', '亂咁～，']
# ['～～', '～～下', '～乾', '頭～～', '頭～～條', '條繩～來', '～來～去，', '兩頭～。']
# ['～過', '～手', '～手～']
# ['佢～下']
# ['一～唔', '唔知～咗']
# ['你老～）', '你老～閪）']
# ['水～得']
# ['巴掌～过']
# ['～佢']
# ['～下']
# ['竹枝～親']
# ['慢慢～過']
# ['～']
# ['～到']
# ['～着']
# ['～去']
# ['～牙）']
# ['～開；', '～屎']
# ['兩邊～晒']
# ['肚腩～下', '～下～下；']
# ['好～。']
# ['眼～）', '透～）']
# ['～水）']
# ['～']
# ['尔處～；', '佢～佢', '亂～休。']
# ['～出']
# ['眼皮～一', '～一～；', '～起']
# ['～起', '～佢', '～起', '～起']
# ['佢~走']
# ['～冧）']
# ['～埋']
# ['喺度～；', '嘢都～澌']
# ['～牛、', '～住']
# ['～到']
# ['～休', '唔好～個']
# ['拳～｜', '佢一～。']
# ['仲冇～開']
# ['一～牙，', '一～']
# ['往南～；', '猪～｜', '～水；', '～油']
# ['～菜；', '～橙']
# ['～埋']
# ['雞籠～，', '拳螺～，', '補']
# ['結～。']
# ['～到']
# ['～扁']
# ['～手', '鼻屎～在', '～死']
# ['～焦']
# ['一腳～入']
# ['～草', '～柴。']
# ['隻人～齊']
# ['～住', '～只', '打工～夠']
# ['～叻│', '你就～大', '佢～熱', '使乜～正']
# ['滑～', '滑～']
# ['～直', '～高', '～高']
# ['～']
# ['～']
# ['我～佢']
# ['就～埋', '記得～細']
# ['～兩']
# ['～個', '心口～(']
# ['～衫。']
# ['論日～到']
# ['～高', '～高', '俾人～休。']
# ['～南｜', '～北；', '～東｜', '～']
# ['樹']
# ['～桌']
# ['～批；', '～貨；', '～定', '橋～。']
# ['～三']
# ['煲水～過']
# ['係咪～有']
# ['～起']
# ['～嘴）']
# ['喫到～']
# ['～頸；', '冇～得']
# ['晚我～了']
# ['着～了']
# ['鞋～脚；', '手機～着']
# ['～']
# ['～']
# ['～粥；', '～龍', '牛']
# ['～灰）']
# ['～頭）', '仲想～？']
# ['～酒）']
# ['下～）']
# ['雞～唔']
# ['唔好～住']
# ['下～底）']
# ['～水）']
# ['佢～冇']
# ['臭尿']
# ['～']
# ['蓋緊～休，']
# ['～z']
# ['腰～）']
# ['～埋', '～得']
# ['～好', '～埋']
# ['～走', '～屋(']
# ['飯鏟～下']
# ['子過～）']
# ['～紅']
# ['蒙～～）', '蒙～～）']
# ['～開）']
# ['樣好～。']
# ['～先）', '～队）']
# ['高']
# ['～c', '～噉']
# ['佢兩～。']
# ['～）', '～噉']
# ['條路～休']
# ['矮矮～', '矮～']
# ['酸～～）', '酸～～）']
# ['發～瘟｜', '爛～。']
# ['～银', '我～起', '～尿；']
# ['禾～；', '一～草｜', '～樹', '兩～繩。']
# ['真係～打；', '～惹(']
# ['～畀']
# ['～）', '～花｜', '～噉']
# ['獃～）', '獃獃～～）', '獃～～）']
# ['樹～）']
# ['～中）']
# ['～燈）']
# ['～糞(']
# ['～齊；']
# ['鞋～腳；', '拖桶～到', '事上～我。']
# ['眼～～）', '眼～～）', '眼～～', '眼～～望']
# ['一頂']
# ['～佬）', '～人）']
# ['～?', '信我～你']
# ['肚']
# ['～隊，', '打']
# ['～埋']
# ['～頸', '～開']
# ['～']
# ['～勻）']
# ['～～', '～～蟲）']
# ['個肚～起', '起個～。']
# ['要人～佢']
# ['～人。']
# ['～雞）']
# ['～']
# ['磨～）']
# ['～離）']
# ['俾人']
# ['～～', '～～聲）']
# ['大聲～我。']
# ['～～', '～～聲）', '喺處～啦；', '啲水～噉']
# ['～d', '～花｜', '～噉']
# ['對頭～一']
# ['～開', '～蓋）']
# ['～皮。']
# ['～返', '～盅；', '閂～道']
# ['對鞋～腳；', '塊石～住']
# ['用磚～高', '～床。']
# ['～～', '～～嗚）', '技術～。']
# ['爛～）']
# ['件衫～晒。']
# ['～狗）']
# ['～水）']
# ['冇要～，']
# ['件衫～地']
# ['～起']
# ['蠶～）']
# ['那～）']
# ['冇使～｜', '狼']
# ['冇使']
# ['一～，', '～']
# ['條褲～到']
# ['～']
# ['～']
# ['狂～～）', '狂～～）']
# ['發～）']
# ['直個～我']
# ['～油']
# ['～趣']
# ['～l', '～～l', '～～l', '哥好～。']
# ['～～）', '～～）', '十年～長。']
# ['～～）', '～～）', '新年～，']
# ['～佢']
# ['手']
# ['鴨～水）']
# ['～）', '～～）', '～～）', '哥好～。']
# ['你點～都', '～佢']
# ['啲菜～乾']
# ['佬仔～地。']
# ['～田；', '～']
# ['暈～“']
# ['～水']
# ['～下）']
# ['過～(', '亂～(']
# ['～望）']
# ['一～）', '叫一']
# ['口～）']
# ['瘦～～）', '瘦～～）']
# ['～紙）']
# ['～蟻）', '～n']
# ['～開）']
# ['你～(']
# ['考試～人']
# ['～爛']
# ['～過）']
# ['～穿）']
# ['個～）']
# ['瓶頸～）']
# ['～爭）', '～～', '～～爭', '個人～。']
# ['～頭）']
# ['摇摇～|', '～得']
# ['～頭。']
# ['發～）']
# ['發～。']
# ['～']
# ['發']
# ['癡～～）', '癡～～）']
# ['老～）']
# ['～錢）']
# ['刀～）']
# ['做～）']
# ['～去）']
# ['～佢', '～姑', '～姑', '～大']
# ['口～～）', '口～～）']
# ['～書）']
# ['眼～']
# ['眼～）']
# ['～衫']
# ['一～”']
# ['～一', '～一～，']
# ['管來～奶']
# ['獃～）', '就好～；', '衫好～。']
# ['眼～）']
# ['～住）']
# ['無得～（']
# ['蕩～：']
# ['～皮）']
# ['用減～少']
# ['～水）']
# ['～竹']
# ['～埋']
# ['一條～，', '～仔']
# ['～呢', '～路']
# ['衫領～晒！']
# ['卒之～咗。']
# ['～眼“']
# ['～兩', '～兩']
# ['～在）', '又冇～在']
# ['～']
# ['一～番', '一～線，', '一～米']
# ['一～角）', '摒埋～。']
# ['起～，', '手']
# ['攞去～一', '～一～。']
# ['鋼琴～喺']
# ['～休']
# ['吱吱～～。', '吱～～。']
# ['日都～住', '老闆～住', '成日～住']
# ['日都～住']
# ['落頭～我；', '～人']
# ['～老', '坎嚟～山']
# ['～蛋）']
# ['～色。']
# ['～吳']
# ['～本']
# ['～蠻）', '見佢～靚']
# ['幾～，', '四～。']
# ['～仔｜', '苦苦～大']
# ['～雾。']
# ['菜凍～咧。']
# ['真係～；', '～晝｜', '食～。']
# ['～）']
# ['～鐘']
# ['～手']
# ['～～', '～～罐', '～粟）']
# ['～條']
# ['～瓜）']
# ['閉']
# ['～滯）']
# ['～！']
# ['成日～〜']
# ['～下']
# ['～球。']
# ['～仔；', '一～飯｜', '一～仔']
# ['嘅嘢～齊']
# ['群～｜', '～佢']
# ['～臭', '菜～爛', '～肥；', '～熟']
# ['～']
# ['一～']
# ['～檯。']
# ['喉嚨～嗮。']
# ['～佔｜', '～定；', '～王。']
# ['水流～～', '流～～到。']
# ['～尾｜', '～回']
# ['～一']
# ['無端～事）']
# ['泥～｜', '～蛇(', '路好～。']
# ['朋友～咗']
# ['趕得～；']
# ['～風）']
# ['冇夠～氣｜', '～肉（', '拉～條', '～錢｜', '～尿（']
# ['～一']
# ['臭～～）', '臭～～）']
# ['～石', '～死']
# ['散～｜', '佮～。']
# ['～']
# ['～我']
# ['～啦；', '睇～）', '睇～你']
# ['～']
# ['～䖢。']
# ['門開～～；', '開～～；']
# ['～開']
# ['～個']
# ['菸頭～）']
# ['塑膠～出', '口冇～得', '用～口', '口機～～', '機～～個', '邊係～實']
# ['～令(']
# ['眼～～｜', '眼～～｜', '～咩', '～咩～！']
# ['立亂～。']
# ['～腸(']
# ['～手。']
# ['～z']
# ['～到']
# ['山好～。']
# ['將佢～起', '～住']
# ['～']
# ['鎖匙～起', '同點～我']
# ['葉～；']
# ['一～錄']
# ['聽佢～。']
# ['～人']
# ['～香']
# ['佢未～錢', '冇～佢', '～人', '擰錢～我。']
# ['～丟']
# ['波珠～。']
# ['～哩?']
# ['～仄；', '擠～。']
# ['～炒｜', '～嘢']
# ['打～炉(']
# ['～隻。']
# ['企人']
# ['帶～把']
# ['一堆～㗎｜', '觀音～。']
# ['你走～快。']
# ['～l', '～l']
# ['～唅', '一咀～到']
# ['淚水～～', '水～～噉']
# ['火星～得', '～撒']
# ['～芽；', '邊啲～出', '佢仔～得']
# ['有～有?']
# ['去噶～。']
# ['淚水～～', '水～～流。']
# ['䊦子～；']
# ['要來～我。']
# ['都冇～人', '～佢', '我唔～你']
# ['～嘢）']
# ['～佢']
# ['橫～街。']
# ['～你']
# ['～頭(']
# ['～嘴；', '接～｜', '～骨。']
# ['～?', '哩～。']
# ['～～', '～～聲）']
# ['～頭；']
# ['～下', '～']
# ['～聲；', '～菸）']
# ['～z', '～都']
# ['叭響～', '響～']
# ['～嘴。']
# ['～律）', '直～(', '尖～(']
# ['溼～～）', '溼～～）']
# ['臭～～；', '臭～～；']
# ['掟隻～過']
# ['～']
# ['～大']
# ['～老）']
# ['～蛋；', '成日～喺']
# ['生～）', '～人。']
# ['灰～）', '屎～）']
# ['～錢｜', '～你']
# ['拉～｜', '剪～。']
# ['～露）']
# ['練習']
# ['～']
# ['～']
# ['你咪～下']
# ['～佬｜', '村～。']
# ['～檯；', '～住', '～人；', '～雞m', '～']
# ['門～）']
# ['一～鎖', '一～頭']
# ['煙塵～在', '堆泥～在', '你～堆', '泥冇～得']
# ['～佢']
# ['～到', '～碗。']
# ['～?']
# ['一～牆。']
# ['塕～；', '煙塵～滿', '蒼蠅～過｜', '幫人～在', '暗～～。', '暗～～。']
# ['一～鎖']
# ['～子）', '幾多～噶。']
# ['～仔']
# ['～屋｜', '～到']
# ['硬～）']
# ['牙～）']
# ['餓～～）', '餓～～）']
# ['畀人～唨', '～生', '噉係～我', '飛我～唨']
# ['～煲）']
# ['～佢', '我毋～你']
# ['煙～～。', '煙～～。']
# ['日去～佢；', '～亲']
# ['～日｜', '～']
# ['鹹～。']
# ['睇～你', '䂿～|', '咬～；', '冇來～你']
# ['～～）', '～～）', '歪歪～～）', '歪～～）']
# ['～脆）']
# ['小心～到']
# ['冇～佢']
# ['餓～～）', '餓～～）']
# ['～仔｜', '苦苦～大']
# ['～）']
# ['眼～。']
# ['頭～|', '心～|', '骨～|', '到肚～|', '肉～。']
# ['驚～）']
# ['勻～）']
# ['～來', '～來～去(']
# ['買皿～|', '等陣～|', '過粒～。']
# ['寡公～）']
# ['～開']
# ['薄～～）', '薄～～）', '短～｜', '矮']
# ['我盃～。']
# ['～花', '個字～咗', '～?', '～晒']
# ['～麪']
# ['直個～我｜', '～檯。']
# ['嘴～', '嘴～']
# ['～水。']
# ['同～）', '你同～；', '箇～年(', '齊上～又', '有下～。']
# ['～草。']
# ['～眼｜', '光～', '光～']
# ['椅～｜', '腳']
# ['～檯', '去～下']
# ['～雞']
# ['垃圾～。']
# ['去～返']
# ['著牛～過。']
# ['～?']
# ['～條', '～身(']
# ['整到～嗮。']
# ['黐～～）', '黐～～）']
# ['～踔）', '一脚～落']
# ['～踔）', '路一～一', '～一～。']
# ['吟～。']
# ['～子）']
# ['～手', '上牀～一']
# ['～早｜', '～機', '～圩；', '～街｜', '～展。']
# ['路好～。']
# ['～痘（', '～痘', '～蟲（', '種米～飯（', '肉冇～油（', '種礦～鐵；', '～水（', '～漿（', '要煠～粒', '得好～一', '好～真']
# ['一～布。']
# ['隻～囉。']
# ['～褲', '～翻', '冇～得?']
# ['驚～；', '～人）']
# ['衣～）', '～衫', '～零']
# ['～大', '～髦。']
# ['頭毛～～｜', '毛～～｜', '劖～', '劖～']
# ['我～先｜', '～人。']
# ['歪～。']
# ['～色｜', '～小']
# ['雞～；', '～袋；', '水蛇～(']
# ['捱～"']
# ['～開']
# ['～～', '～～地。']
# ['～紙。']
# ['渠～渠']
# ['做冇～｜', '跟冇～。']
# ['人哋～。']
# ['～衰｜', '死命～佢。']
# ['～傷｜', '打球～親']
# ['～下']
# ['～脹）', '～咩？']
# ['～發']
# ['男人']
# ['大水～咧']
# ['～爛']
# ['抽～。']
# ['～衫｜', '～裝。']
# ['祈冇～到']
# ['我諗～冇']
# ['～頭', '～鬍', '韭菜～髙']
# ['咪～我；', '～到', '小心～瀉', '～著', '蒸汽～過']
# ['儱～）']
# ['酒～；', '一～酒。']
# ['～張']
# ['啲書～出', '～衫；', '～電）']
# ['盤菜～出', '硬硬～畀']
# ['日整～隻']
# ['你好～喎｜', '～世；', '～佢']
# ['左邊～出']
# ['～你']
# ['有條～㗎；', '～口。']
# ['凐～～。', '凐～～。']
# ['～）']
# ['～褲']
# ['～鎖']
# ['緊書～｜', '食飯～。']
# ['千文～；', '時間～。']
# ['垃圾～）']
# ['～魚）']
# ['我還～我', '冇～佢']
# ['～雞│', '～肥']
# ['～雜）', '咪～｜', '～喧', '～天']
# ['毛～～）', '毛～～）']
# ['其～我', '～鳥；']
# ['～']
# ['著煙～到｜', '～鼻。']
# ['扮幾～喎；', '～佬。']
# ['邊個～邊']
# ['～）']
# ['～～）', '～～）']
# ['得咁～，']
# ['～天', '～頭']
# ['老虎～走']
# ['頭～湯。']
# ['～定(']
# ['～民。']
# ['件衫～那', '衣裳～在', '開車～人｜', '～車｜', '～船；', '～梯；', '～電｜', '～網。']
# ['～溼；', '～住', '～渧）']
# ['～埋', '一～']
# ['五點～']
# ['～啲']
# ['一～地']
# ['雞～']
# ['溼～～）', '溼～～）']
# ['乜']
# ['箱你～落']
# ['難～；', '～死。']
# ['你～在']
# ['酸～～）', '酸～～）']
# ['～啲']
# ['大聲～我；', '～）']
# ['～屁）', '～牛']
# ['瘟']
# ['攞嘢～到']
# ['～我', '～水；', '果去～外', '～我', '～出']
# ['重～）']
# ['冇～得', '～秤；', '你～佢', '我～小', '～家', '～家']
# ['～']
# ['頭～～｜', '頭～～｜', '～頭', '～頭～腦。']
# ['～跤。']
# ['隕石～死', '～到']
# ['花瓶～在', '成日～在']
# ['邊～。']
# ['你～在']
# ['矮～～。', '矮～～。']
# ['定～；', '厚～～）', '厚～～）']
# ['冇～我']
# ['毋～佢']
# ['～毒）']
# ['狗～。']
# ['隻貓～換']
# ['～利', '～錢。']
# ['～手']
# ['～咁']
# ['做～｜', '詐～｜', '特別～噶。']
# ['軟～～｜', '軟～～｜', '髧～', '髧～']
# ['煲好～。']
# ['～米。']
# ['冇得～水。']
# ['底啲～來', '～來～去。']
# ['條棍～實', '張紙～上。']
# ['～～', '～～佬｜', '～～', '～～公。']
# ['慢慢～乾']
# ['蘋果～。']
# ['揾笪～坐']
# ['得肥～～。', '肥～～。']
# ['酸～～）', '酸～～）']
# ['豬～|', '豬腳～。']
# ['～佢！']
# ['大聲～佢。']
# ['～～。', '～～。']
# ['～～|', '～～|', '～闃']
# ['～']
# ['軟～～。', '軟～～。']
# ['發～。']
# ['漦～～）', '漦～～）']
# ['軟～～。', '軟～～。']
# ['對～。']
# ['麻～）']
# ['傻傻']
# ['～～d', '～～d']
# ['～d']
# ['我～。']
# ['關得～嘹。']
# ['～燈', '～佢', '～佢']
# ['～惜）', '仔夠～哦。']
# ['～尿(', '～']
# ['～腳｜', '～起']
# ['～過', '搞～；', '橫打～｜', '橫睇～睇。']
# ['～廢｜', '～佬｜', '又發～喇。']
# ['爐度～熱']
# ['暫～。']
# ['打～；', '～色）']
# ['～閪；', '人好']
# ['甜～，', '少']
# ['響～｜', '燵']
# ['～隻']
# ['得咁～錢，']
# ['～～', '～～聲；', '屙～～。', '屙～～。']
# ['～好', '～～', '～～平']
# ['～下', '～身']
# ['～一']
# ['李要～甘', '～料(']
# ['起身～～', '身～～個｜', '～?']
# ['電線～落', '啲啲～～；', '啲～～；', '水～～。', '水～～。']
# ['～落', '～?']
# ['臭～｜', '臭水～。']
# ['～c']
# ['圓～d']
# ['～口｜', '開～｜', '豬肉～。']
# ['～街。']
# ['～光）']
# ['大～）']
# ['面～～。', '面～～。']
# ['～']
# ['～蟲｜', '～蟲', '～老']
# ['～桃']
# ['～好；', '～係）', '我～行']
# ['百文～']
# ['邊～；', '釘幾']
# ['一～味；', '氣～）', '佢啲～特']
# ['慢～）']
# ['～?']
# ['陰澳～。']
# ['一～屎。']
# ['～下', '～灰(']
# ['黃坡～。']
# ['西貢～。']
# ['手～）']
# ['碟菜～上']
# ['～你']
# ['～水', '～雨']
# ['日好～；', '食～嘢']
# ['一拳～過']
# ['～塊']
# ['第一～。']
# ['肥～～）', '肥～～）']
# ['覺又～起']
# ['佢冇～我；', '吓到～都', '冇敢～。']
# ['～c']
# ['～斷。']
# ['～z']
# ['齊工～｜', '完飯～。']
# ['見親～到']
# ['～大', '～']
# ['頸～～｜', '頸～～｜', '～頸']
# ['聲冇～就']
# ['上好～；', '冇～我']
# ['飽打～。']
# ['冇～咁', '阿媽～你', '你～做']
# ['～口）']
# ['睇～。']
# ['下你～']
# ['又冇～著']
# ['～']
# ['～生；', '又執～英']
# ['在啲～有']
# ['子揸～會']
# ['～弓(']
# ['～覺；', '～低。']
# ['佢～人']
# ['佢冇～得', '～得｜', '～輸｜', '好冇～得。']
# ['馬屎～；', '掃管～。']
# ['一～地｜', '邊一～。']
# ['屎～臀｜', '屎']
# ['行路～～', '路～～聲｜', '～一']
# ['議挨～矣｜', '朋友～矣；', '～出']
# ['～～', '～～聲｜', '車轆～～', '轆～～聲']
# ['～）']
# ['佢好～㗎。']
# ['咁閪～｜', '你好～。']
# ['紅～～。', '紅～～。']
# ['風～｜', '花～(']
# ['～髮）']
# ['～仔；', '又～唨']
# ['幾多～嘅？']
# ['條索～起']
# ['書～｜', '作業～。']
# ['麻～）']
# ['～']
# ['～被。']
# ['吹得～～', '得～～聲。']
# ['～法）', '搞咩～。']
# ['一～牆。']
# ['佢冇～我']
# ['～禮；', '一～炮。']
# ['～）']
# ['一～地。']
# ['屋好～；', '件衫～過', '有幾～；', '～佬。']
# ['～下｜', '而～。']
# ['～鎖；', '口水～|', '漦～；', '日～；']
# ['三～飛']
# ['～勢）']
# ['咩來～；', '是你～？']
# ['通～）']
# ['～仔｜', '～妹｜', '～話。']
# ['丟～）']
# ['～塊', '～佢']
# ['～褲。']
# ['啲魚～幾', '～木']
# ['押～。']
# ['嚿石～住']
# ['～丟']
# ['～工；', '～倉；', '～佢']
# ['香～。']
# ['挑肥～']
# ['～開']
# ['傻～）']
# ['肉～；', '煲～；', '調～；']
# ['～口）']
# ['～水']
# ['～蟲）']
# ['一～地']
# ['～幫｜', '～份；', '好～。']
# ['肩～）', '肩～骨）', '一～燒']
# ['～曱）']
# ['硬～；', '真心～。']
# ['～擦｜', '擦～；', '～鞋。']
# ['西～。']
# ['東～。']
# ['～飛）', '命來～。']
# ['浸兩～，', '以爲～圍；', '牙～。']
# ['門～；', '～剪）']
# ['三～兩', '快就～咗。']
# ['打～；', '爭～。']
# ['～']
# ['挽～｜', '火～｜', '焫～｜', '吹～。']
# ['乌～；', '～。']
# ['支筆～好']
# ['～你', '條好～未？', '我～你', '冇～食', '又冇～睡；', '～下']
# ['傾～）']
# ['～n']
# ['～肋']
# ['～住']
# ['洗兩～先']
# ['～著｜', '去～我']
# ['都冇～食']
# ['水好～；', '冰櫃～下。']
# ['～瑟', '掹～條', '～住']
# ['～係｜', '你死～嘞。']
# ['～皿']
# ['磚頭～台', '～住']
# ['坡好～。']
# ['快啲～埋。']
# ['～實']
# ['～']
# ['耳～）']
# ['～']
# ['用刀～减']
# ['你～去', '～']
# ['～瘩）', '打']
# ['～n', '好閪～，', '事又']
# ['～高；', '～雞）', '～鐖）', '摱～鐖。']
# ['都冇～得?', '～竿；', '屎胐～～；', '胐～～；']
# ['眼～～）', '眼～～）']
# ['腰']
# ['～屘｜', '～']
# ['我～知']
# ['一～肉｜', '一～泥｜', '一～屎；', '一～水。']
# ['～按']
# ['我～夢']
# ['老～。']
# ['～度｜', '～']
# ['～']
# ['我好～～', '好～～到', '我至～蟲。']
# ['～筋(']
# ['上～。']
# ['～餸、', '～']
# ['苦～。']
# ['～n']
# ['條繩～到', '出來～我。']
# ['～街｜', '南寧～。']
# ['撈佬～普']
# ['儂～）', '～湯(']
# ['搞～｜', '～佬。']
# ['搞～｜', '～佬。']
# ['～g']
# ['～多；', '風景～令']
# ['～～g', '～～g']
# ['～死', '水泥～下']
# ['～）']
# ['～夾）', '～之）', '～路']
# ['～惜）']
# ['料夠～冇？']
# ['我～佢', '你～如']
# ['地底～休']
# ['咁～']
# ['～l']
# ['真係～。']
# ['～帽）']
# ['～地，', '～檯']
# ['鼻～）']
# ['～～', '～～子）']
# ['～本']
# ['～～）', '～～）']
# ['冇～啊，']
# ['都挨～溼']
# ['～火']
# ['～皮(']
# ['打鑊～']
# ['好好～']
# ['～犀', '得紗～亂。']
# ['黄～～。', '黄～～。']
# ['袋米～上']
# ['～個']
# ['～）']
# ['～寒）']
# ['牛']
# ['整']
# ['你～下？', '開']
# ['一～飯。']
# ['～仔｜', '講']
# ['～住', '～住']
# ['～氣(', '～']
# ['～著）']
# ['～腳）']
# ['硬～｜', '生～。']
# ['肚～）']
# ['～狗']
# ['我～']
# ['～仔｜', '～']
# ['～～', '～～聲', '一口～齊']
# ['～老']
# ['腳～｜', '手']
# ['場咁～。']
# ['肚好～｜', '酸嘢～肚。']
# ['唔係～？']
# ['～嘴。']
# ['我飲～咖']
# ['手']
# ['滿～。']
# ['職權～矣', '～佢']
# ['～肚；']
# ['懶～。']
# ['內～）']
# ['腳～。']
# ['～件']
# ['硬～～）', '硬～～）']
# ['～']
# ['畀人～晒']
# ['火～）']
# ['紅～～。', '紅～～。']
# ['詭～）', '牛～仔(']
# ['褲爆～；', '魚多～。']
# ['～子）']
# ['～頭；', '菜～。']
# ['～隻', '～穿']
# ['～袖）']
# ['～頭；', '鉛筆～嘹。']
# ['我大～你；', '愛～；', '再來～；', '燈～矣。']
# ['天～｜', '冇夠～；', '身就～咧。']
# ['～嘴）']
# ['黑～～。', '黑～～。']
# ['食～冇']
# ['～氣。']
# ['～平']
# ['老～）']
# ['一～豆']
# ['黃～魚）']
# ['～杯', '～水。']
# ['個窿～入', '～來', '～來～去。']
# ['個窿～入', '～來', '～來～去。']
# ['～人。']
# ['就多～；', '掹～(', '咳～(']
# ['～仁；']
# ['蘇～）']
# ['喇～）']
# ['一～子；']
# ['唔好～到', '部車～親；', '～身。']
# ['脷好～。']
# ['～n', '～雞）', '～子）', '～卵）']
# ['呼～；', '～佢']
# ['～洒）', '覅咁']
# ['～溼）', '～佬；', '～嘢。']
# ['哥好～。']
# ['蘋果～隻', '冇～張']
# ['老～）']
# ['～路。']
# ['～']
# ['～魚。']
# ['～打；', '～數(']
# ['麻～煩｜', '咁～多']
# ['～得', '～你']
# ['～燈；', '整～火。']
# ['小心～入']
# ['～～', '～～玩']
# ['姣婆～嫁｜', '我好～有']
# ['～了', '一棍～過', '～雞']
# ['臭～～｜', '臭～～｜', '～巴']
# ['～～', '～～下', '～乾', '頭～～', '頭～～條', '條繩～來', '～來～去，', '兩頭～。']
# ['～穀。']
# ['花生～']
# ['～飯｜', '～錢；', '～兒）', '～人']
# ['～?', '講打～係']
# ['～']
# ['～實']
# ['你～去']
# ['够～；']
# ['咩咁～噶；', '出去～啦。']
# ['啲書～晒']
# ['～～', '～～～。', '～～～。']
# ['～仔。']
# ['～腳。']
# ['～唅）']
# ['～建；', '～旺；', '時～｜', '家下～學']
# ['～致；', '得我～～。', '我～～。']
# ['婆咁～嘅？']
# ['西餐～；', '一陣～。']
# ['你～下']
# ['～仔。']
# ['～拳', '～腳']
# ['～，']
# ['飯～；', '隻雞～；', '一～水。']
# ['～穿', '～爛']
# ['～崩）']
# ['紅～｜', '橫頭～。']
# ['～～', '～～聲｜', '轠～～｜', '轠～～｜', '衝～', '衝～']
# ['～唪', '～隻', '～二', '～世。']
# ['馬齒～｜', '肥肉～(']
# ['馬齒']
# ['～味；', '～噙', '口～～', '口～～大', '荷包～唨。']
# ['～火(', '～熱；']
# ['～沙。']
# ['～眼']
# ['～穿']
# ['～瓜']
# ['因住～出']
# ['～火｜', '～煤']
# ['成日～我｜', '呼呼～～。', '呼～～。']
# ['～開）', '指甲～條']
# ['喺度～。']
# ['～暑|', '日好～。']
# ['～熱。']
# ['氣好～；', '打～火', '～過', '唔夠～。']
# ['肚～）']
# ['打趁～）', '叉趁～）']
# ['黃～）', '～']
# ['油～味，', '臭油～。']
# ['我～都']
# ['～相；', '你～着']
# ['今晚～第']
# ['你～搏']
# ['～文', '～文～武。']
# ['拜～。']
# ['～j']
# ['～飯。']
# ['～溼']
# ['橡筋～矣；', '條蟲～來', '～來～去。']
# ['青～～。', '青～～。']
# ['青～～。', '青～～。']
# ['咿咿～～）', '咿～～）']
# ['～子）']
# ['～上']
# ['佢哋～緊']
# ['就咁～。']
# ['知我～；', '～嘢|', '成績～|', '人品～。']
# ['毛']
# ['～罾）']
# ['鍾意～']
# ['你～好', '～凳', '～拼']
# ['坐車～｜', '～～', '～～讀']
# ['～住）', '～畀']
# ['特別～；', '識幾～。']
# ['～落。']
# ['～巡；', '行～睇', '～睇～。']
# ['風～喇。']
# ['～～。', '～～。']
# ['灯一～一', '～一～；', '～眼(']
# ['～動；', '～手。']
# ['～你', '就來～你', '～係｜', '～冇｜', '～咪；', '紅～紅。']
# ['隻橙～啊']
# ['仔好']
# ['得好～啊；', '喺度～我']
# ['我～你']
# ['～）']
# ['字好～；', '～滑。']
# ['～隻', '我～一', '～所', '我做～作', '我～做', '我～做', '我學～羽']
# ['渠好～啊。']
# ['你～到']
# ['蘭花～弄；', '佢好～，']
# ['兩仔～｜', '有～生']
# ['太～了，', '身太～了。']
# ['跳～', '跳～']
# ['笑～～）', '笑～～）']
# ['～利；', '賭輸～；', '趕得～食', '做得～人。']
# ['油～～）', '油～～）', '融～～）', '融～～）']
# ['～撈', '～你']
# ['難～得']
# ['～，', '～，']
# ['～到', '～街']
# ['～憸）', '～尖）']
# ['小']
# ['～蛇）']
# ['～荽）']
# ['墻真～，', '病真～，']
# ['～飯。']
# ['屋咁～，', '～到']
# ['～）']
# ['得咁～ ', '我咁～呢。']
# ['～鹹', '衫都～鹹', '汗～到']
# ['穿兩～衫｜', '薄～～。', '薄～～。']
# ['竟然～我', '～手）']
# ['～，']
# ['環九～；', '田九～。']
# ['～～', '～～睇']
# ['～苗；', '魚～。']
# ['得好～。']
# ['～下', '攞水～下']
# ['飛～）']
# ['嘈～休，', '哭～']
# ['臭水～"']
# ['整到～嗮｜', '著洗～嘹。', '～再']
# ['～或）', '拜一～礼']
# ['你好～啊。']
# ['好鬼～']
# ['冇使～']
# ['～荽）']
# ['～頸。']
# ['粥～）']
# ['～l']
# ['～把']
# ['老']
# ['～定）', '咩你～要']
# ['一～牌。']
# ['小心～著', '～']
# ['～開']
# ['～叉）']
# ['糖～）']
# ['球好']
# ['～佢', '脫～；', '～媽｜', '～爺。']
# ['有啲～；', '络好～。']
# ['額～｜', '礐']
# ['屌～）']
# ['～l']
# ['～～。', '～～。']
# ['～打｜', '～生(', '手機～噢。']
# ['～佢']
# ['～住']
# ['～牆｜', '～樹。']
# ['～蟧）', '～蜍）']
# ['滿～）']
# ['屋高～休。']
# ['～']
# ['佢～讀', '～力。']
# ['雞～。']
# ['佢好～；', '祈冇～壞', '屋企～廣']
# ['嘢好～；']
# ['梯級～到；', '～岌）']
# ['～印；', '～被；', '～電']
# ['～）']
# ['捱狗～一']
# ['～～', '～～']
# ['～水(']
# ['～埋']
# ['～檯', '～檯～']
# ['～女|', '～妹。']
# ['～鐖(']
# ['一～。']
# ['屋～）', '你在～冇？']
# ['石～）']
# ['一～樹']
# ['～离(']
# ['咳～～｜', '咳～～｜', '笑～～。', '笑～～。']
# ['一～柱｜', '一～?']
# ['膠']
# ['～一', '～一～䊆', '條棍～下｜', '～牙']
# ['圍～街。']
# ['木']
# ['～～｜', '～～｜', '～～', '～～咳｜', '～～', '～～']
# ['～淨。']
# ['～佢']
# ['㱥～）']
# ['瘦～～）', '瘦～～）']
# ['～屎）']
# ['～轉。']
# ['公']
# ['笑～～）', '笑～～）']
# ['巴～～）', '巴～～）', '膠膠～～）', '膠～～）']
# ['尥～）']
# ['～隔']
# ['筷子～一', '～一～；', '～過']
# ['～']
# ['露～。']
# ['終於～嘹。']
# ['镽～）']
# ['～頭）']
# ['繚～）']
# ['蟥～）', '～乸）']
# ['～～', '～～欦']
# ['咁～嘅']
# ['～']
# ['拖桶～到', '事上～我；']
# ['～之）']
# ['～魚）']
# ['～開']
# ['響度～乾']
# ['～）']
# ['水要～下']
# ['啲油～晒｜', '～油(']
# ['～受。']
# ['到條～來']
# ['～書。']
# ['做乜～啊。']
# ['得咁～；', '～妙。']
# ['諗條～。']
# ['～蝦｜', '～燒。']
# ['～瓜']
# ['谷木～；']
# ['臭']
# ['乾～；', '～乾', '晚好～。']
# ['～被。']
# ['羣人～過']
# ['～牀）', '～枕。']
# ['～閬）', '～高']
# ['蚂螂～）']
# ['～桶；', '鐵～｜', '橡筋～｜', '膠～｜', '頭～；', '～頸', '～頭', '～煲）']
# ['～腿｜', '～腰；', '特羅～嘹；', '條棍～～', '棍～～個。']
# ['～血｜', '～瘕。']
# ['一～芭']
# ['～成']
# ['～丟。']
# ['左手～）', '右手～）', '高腳～）']
# ['～～）', '～～）']
# ['歪歪～～。', '歪～～。']
# ['四方～；', '一個～；']
# ['高～～；', '高～～；', '鬆～', '鬆～']
# ['鴨']
# ['一～蚊']
# ['～火']
# ['～']
# ['亮～～）', '亮～～）', '額頭～。']
# ['～件']
# ['～到｜', '～跌。']
# ['筷子～盤']
# ['～過']
# ['仄～）', '戴仄～嘹。']
# ['就唔～嘞｜', '～執。']
# ['蠄～）']
# ['中意']
# ['～起']
# ['一～木。']
# ['～風）']
# ['我心～住', '～住～住。']
# ['～嘢（']
# ['～衫', '～成']
# ['～口）', '油～）']
# ['大～～）', '大～～）', '～幾']
# ['～～', '～～聲）', '～～', '～～臨）', '～清']
# ['～䕢）']
# ['～尾｜', '～']
# ['～']
# ['～開']
# ['長～｜', '～～k', '～～k']
# ['～啲']
# ['～我', '～～', '～～挨']
# ['～']
# ['燒到～～', '到～～聲。']
# ['～抱。']
# ['～嘢；', '～耍。']
# ['你去～～', '去～～佢。']
# ['～線｜', '～衫。']
# ['儱～）']
# ['冚唪～）']
# ['～']
# ['～一']
# ['～魚）']
# ['～。']
# ['膚會～痛；', '～皮。']
# ['一～']
# ['籬～）']
# ['～）']
# ['邋～）']
# ['～薑；', '得夠～。']
# ['講～｜', '～佬。']
# ['～攪）']
# ['～?', '嘢好～']
# ['有條～。']
# ['你條～呢？']
# ['幫佢～狗']
# ['話真～。']
# ['魚要～幾']
# ['～']
# ['堆啲～乜；', '棍來～下']
# ['上去～手；', '～']
# ['～s', '咁鬼～s']
# ['～菶']
# ['～竹）']
# ['雞～。']
# ['花']
# ['好～。']
# ['～把）']
# ['塊布～實']
# ['稀～～）', '稀～～）']
# ['～花｜', '～水｜', '～']
# ['～堆│', '啲磚～起', '一～磚│', '一～水']
# ['～材']
# ['～子｜', '～核。']
# ['當面～佢；']
# ['～']
# ['水溝～）']
# ['手～到', '冇系～到']
# ['麻～煩｜', '咁～多', '獨～。']
# ['頻～）', '頻頻～～；', '頻～～；', '～爛']
# ['圾桶～唨。']
# ['上擺～雜']
# ['～口', '著嘢～']
# ['挨你～爛']
# ['～蹬）', '跳～～。', '跳～～。']
# ['～繒）', '～n']
# ['起～。']
# ['～多', '豬～；', '執～）']
# ['久會']
# ['不～）', '直～(']
# ['馬～）']
# ['～衫', '～厘', '～厘～?', '冇～得']
# ['蚊蠅～住｜', '螞蟻～死']
# ['～空(', '白蟻～嘹｜', '齒捱～嘹。']
# ['披條～。']
# ['不～）', '一～）', '～m']
# ['～佢']
# ['～嘢；', '～f']
# ['就～佢']
# ['～b', '衫好～。']
# ['～把']
# ['飯要～匀']
# ['豬腳～；', '～']
# ['～h']
# ['斜～眼。']
# ['奇～）']
# ['～啡）']
# ['書好～。']
# ['大～。']
# ['火尾～到｜', '～黑；', '～豬']
# ['～衫']
# ['眼～；']
# ['狗要～幾']
# ['～地；', '～落', '～牀(']
# ['～殑）', '瘦～。']
# ['～核｜', '～骨']
# ['好多～。']
# ['～迍）', '今次～喇，']
# ['～日｜', '～晚｜', '～隻']
# ['～斤']
# ['～食）']
# ['～瓜', '～雞', '～魚']
# ['～狗；', '飢～～。', '飢～～。']
# ['～頭']
# ['空～～｜', '空～～｜', '手喇～。']
# ['尥～）']
# ['～哥）']
# ['～高']
# ['～一', '～']
# ['～?', '～']
# ['～繑）']
# ['疏～；', '撈～；', '菜～；', '～豆']
# ['～番']
# ['疏～。']
# ['～住']
# ['～毛）']
# ['～l']
# ['～～', '～～臨', '～噉']
# ['～～l', '～～l', '～就']
# ['使～。']
# ['眼～；', '口咁～。']
# ['～']
# ['腳']
# ['一～地|', '一～']
# ['～']
# ['～貼）', '豬']
# ['車～；', '～船。']
# ['～']
# ['車～。']
# ['一～']
# ['鞋亮～休｜', '']
# ['一～膠', '一～豬']
# ['八點～鐘。', '萬～文。']
# ['穀']
# ['茅～。']
# ['肚～）']
# ['～～', '～～攣）']
# ['摥～(']
# ['波有～｜', '～?', '圓～～。', '圓～～。']
# ['落雨～；']
# ['喉嚨～。']
# ['～']
# ['都係～過']
# ['有啲～｜', '～餅(']
# ['～風｜', '～空']
# ['條索～著', '蔸腿～著。']
# ['老～）']
# ['南寧～北', '～屋；', '～多', '～仔。']
# ['～成']
# ['飯菜～～', '菜～～聲']
# ['～～', '～～聲）', '佢～趯']
# ['～萁）']
# ['冇識～你']
# ['～～）', '～～）']
# ['～高']
# ['螞～）', '螞～?']
# ['～']
# ['大笪～痕。']
# ['～埋｜', '～～', '～～']
# ['捱車～到｜', '～唅']
# ['走～', '走～']
# ['哭～～。', '哭～～。']
# ['裨～（']
# ['佢～得', '冇想～你。']
# ['～膇）', '得好～；', '佢好～個。']
# ['～勻；', '我～佢']
# ['肥～｜', '跛～；', '豬肉～｜', '泥水～。']
# ['細～仔）', '細～哥）', '細～）']
# ['一條～作']
# ['有一～印｜', '成一～。']
# ['～佢']
# ['山上～落', '～滑', '～只', '～跌。']
# ['筍大～哦｜', '斷～。']
# ['眼～～；', '眼～～；', '～大']
# ['～出2']
# ['肚～。']
# ['一～']
# ['～份', '～鬍']
# ['腰～。']
# ['睡覺～。']
# ['摥～(']
# ['～好']
# ['隻蛋～喇。']
# ['鐵～，', '皮～。']
# ['穿你～']
# ['～偅）', '成日～所']
# ['～手']
# ['等～｜', '諗～。']
# ['等～｜', '諗～。']
# ['黑～～）', '黑～～）']
# ['～毛。']
# ['地上～｜', '～']
# ['大～）']
# ['～）']
# ['水～。']
# ['～係']
# ['一～']
# ['大～声）']
# ['～賴l']
# ['～鼻。']
# ['～胡(']
# ['冇要～上', '～丟｜', '～數(']
# ['～一', '你手～到', '～得']
# ['黑～；']
# ['～佢│', '背後～。']
# ['～竹', '～上', '～山｜', '屋頂～過']
# ['～～）', '～～）']
# ['阿～）']
# ['～房.']
# ['工就～住']
# ['草地～住']
# ['～嘢', '你～罵', '今日～來。']
# ['～螂?', '～蟻）']
# ['～仔）']
# ['～大', '～大']
# ['～定；', '～條', '～雞；', '冇得～。']
# ['～皮｜', '番～(', '亞']
# ['三兩～啲。']
# ['係咪～㗎；']
# ['熱頭～；', '～噉', '～噉', '佢好～；']
# ['～牙｜', '～角；', '手～｜', '～嘴。']
# ['紅酒～唨。']
# ['～頭。']
# ['～兒｜', '～g']
# ['噉～得']
# ['～針(']
# ['一～']
# ['～蝞）']
# ['～頭；', '～低；']
# ['～痣。']
# ['毛～）']
# ['條蛇～回']
# ['一～銀。']
# ['～講。']
# ['～淚｜', '～屎']
# ['～先）']
# ['一對～。']
# ['天～～', '天～～']
# ['眼']
# ['黑～', '黑～']
# ['～蝞）']
# ['～䒏）']
# ['～嘢。']
# ['蚊～｜', '～仔。']
# ['～朝；', '～晏；', '～']
# ['手']
# ['阿爸～唨']
# ['蚊蟲～在', '多人～｜', '覅去～人']
# ['淡～～）', '淡～～）']
# ['你阿～｜', '你老～；', '～脂。']
# ['屌～）', '㞗～）']
# ['你睇～？', '睇緊～？', '～嘢。']
# ['～斜）']
# ['～開']
# ['～開', '～書｜', '～到']
# ['你就～開。']
# ['～回']
# ['舞～）']
# ['孻～。']
# ['～眼；', '聽我～一']
# ['塘～）', '～）']
# ['我眼～～', '眼～～到。']
# ['～摩。']
# ['塘～）', '～）']
# ['貓～）']
# ['～水(']
# ['～一']
# ['啲水～喇，']
# ['仲～食']
# ['～衫；', '～藥；']
# ['喫多']
# ['～嘴；', '佢好～佢']
# ['～痘']
# ['撓痕～出']
# ['～開｜', '～紙。']
# ['～摩｜', '～挲。']
# ['裝']
# ['～地']
# ['你又～啲']
# ['約～）', '約～就']
# ['一～電']
# ['～仔｜', '～～。', '～～。']
# ['一～']
# ['～見｜', '～定', '～路；', '外婆～我']
# ['咁閪']
# ['～～', '～～']
# ['～佬｜', '使咁～；', '～番', '～心']
# ['發～）']
# ['～了']
# ['做～）', '～']
# ['臭']
# ['一蔸～；', '你咁～噶']
# ['～個', '～個']
# ['～身）']
# ['天～']
# ['我～喇；', '～懂）', '我～喇｜', '老']
# ['一～蔗｜', '一～牆']
# ['面好～；', '～茶']
# ['孭～）']
# ['～簁）', '好咁']
# ['雞～｜', '～型(']
# ['白話～到', '細車～到，']
# ['～齋｜', '～']
# ['塊布～一', '～一～就']
# ['一']
# ['～']
# ['～水）']
# ['腰骨']
# ['真係～噢｜', '～頂｜', '～抵。']
# ['～佬）']
# ['外頭～到']
# ['～(', '～釦(']
# ['～袋）']
# ['～～｜', '～～｜', '粈～～｜', '粈～～｜', '～', '～']
# ['～條']
# ['～～。', '～～。']
# ['～']
# ['～，', '～，']
# ['～佢；']
# ['～。']
# ['冰箱～咧｜', '機睇～雙']
# ['好～；']
# ['搵路～。']
# ['你～粒']
# ['～牙）']
# ['～住', '～住', '～聲']
# ['～痛）']
# ['～汁）']
# ['～咗']
# ['耕']
# ['泥']
# ['～掣(', '～開', '～菜；', '～ ', '～化"']
# ['融融～～｜', '融～～｜', '有幾～罵', '罵幾～！']
# ['～n']
# ['～膎）']
# ['～）']
# ['～～', '～～痛）']
# ['事好～。']
# ['佢好～，']
# ['～嫩）']
# ['～凸。']
# ['一～']
# ['～手', '～番', '～斷']
# ['曬～～）', '曬～～）', '頭大～～）', '大～～）', '痛～～）', '痛～～）']
# ['～死']
# ['激～。']
# ['～乾', '～開', '～偈）', '～紋）']
# ['湯好～；', '係咁～啩。']
# ['角～、', '屋']
# ['正～｜', '特～｜', '公～。']
# ['～葡']
# ['乜嘢～；', '十文～我', '意你～。']
# ['邊～）']
# ['～嘢', '～鬮。']
# ['～子', '～子）']
# ['喺度～菜。']
# ['～～', '～～雞。']
# ['鱼～。']
# ['一～帽。']
# ['生咁～仲']
# ['用泥～公', '～高', '～高', '～牙', '～米', '～乾', '～拳']
# ['都行～嘹。']
# ['～']
# ['老～子）']
# ['～～', '～～仔）']
# ['～鷹。']
# ['唱～）']
# ['又要～住']
# ['～?', '人好～，', '～冇']
# ['～佬 ', '～話。']
# ['～～', '～～聲）']
# ['銀～。']
# ['毒頭～）']
# ['一～']
# ['一～水；', '一～屋。']
# ['去我～冇', '～冇', '輸～；', '企～。']
# ['東～西', '～西～｜', '～諰(']
# ['臭～。']
# ['生～～）', '生～～）']
# ['～n', '有啲～喎。']
# ['～魚）', '～翻', '～動']
# ['長～～。', '長～～。']
# ['～框｜', '床板～嘅，', '度門～晒']
# ['大車～壞']
# ['㥛氣～～）', '氣～～）']
# ['～牆']
# ['你咁～，']
# ['～?']
# ['～瓜']
# ['磚～）']
# ['～）']
# ['你～我。']
# ['著隻～?', '車啲～仔']
# ['風吹～休。']
# ['～～｜', '～～｜', '～妹。']
# ['茶～。']
# ['咁～嘅', '～雷。']
# ['手～腳', '～腳']
# ['快就～個；']
# ['～～', '～～喫）']
# ['亂～廿', '～得', '得就～。']
# ['～s', '～s']
# ['發尿～）']
# ['腰～。']
# ['佢～落']
# ['卅幾～嘹，']
# ['水果～喺']
# ['木～；']
# ['～d', '發～。']
# ['～都', '冇得～；', '～～', '～～子）']
# ['～近｜', '～着']
# ['一～）', '未去～，']
# ['崖以～～｜', '以～～｜', '得牙～～', '牙～～到，']
# ['到就～。']
# ['～）']
# ['齮']
# ['啲蟲～壞']
# ['～來', '～來～去｜', '～凳；', '～時', '跟啲～｜', '～價。']
# ['～n']
# ['～齕）', '～～', '～～齕', '～～', '～～吟']
# ['～厠', '厠所～得']
# ['～頭', '～頭～腦）']
# ['喺度～。']
# ['～頭。']
# ['係度～。']
# ['狗～｜', '飯～。']
# ['食到～；', '～到']
# ['～高']
# ['曲～；', '～過']
# ['一～']
# ['撅～）']
# ['油～；', '細～；', '耍～嘹。']
# ['行到～，', '做到～，', '笑到']
# ['～n']
# ['幫我～本', '～火']
# ['～轉']
# ['毒頭～）']
# ['天冷～近']
# ['～脬(']
# ['～來', '一～米。']
# ['～']
# ['～了']
# ['～單']
# ['～樓', '～上', '一腳～你']
# ['發～|', '到我～澌。']
# ['～下', '雞公～(']
# ['三～蟲）']
# ['肉太']
# ['～']
# ['雞～；', '左～。']
# ['芿～～。', '芿～～。']
# ['就想～～', '想～～佢']
# ['你～住', '～衫']
# ['瘦～|', '肥']
# ['件衫～溼|', '房間～亂|', '地底～滑|', '碗～肥。']
# ['～～', '～～笑）']
# ['～n', '扮煮～n', '玩～～|', '玩～～|', '走～n']
# ['～水｜', '～茶｜', '～酒；', '齊去～。']
# ['之前～兩']
# ['～定）', '你～定']
# ['～你', '～夠(']
# ['大～）', '大～聽', '～睇', '～睇～｜', '～頋', '～頋～。']
# ['逳就～。']
# ['～｜', '到我～一', '～一～。']
# ['～腳；', '～來', '～來～去。']
# ['～實']
# ['頭髮～成', '～荛', '之毛～。']
# ['～n']
# ['～n']
# ['～菜']
# ['一～毛。']
# ['～屋；', '～邊。']
# ['～腳']
# ['好～咬', '番薯']
# ['～']
# ['吉～）']
# ['～黑']
# ['糖～蟻', '～一', '糖會～痰；', '冒會～人。']
# ['有～睇；', '做～；', '隻～唔']
# ['～高', '～高']
# ['乞～｜', '仔～｜', '妹～｜', '貓～。']
# ['～～', '～～忸', '論日～。']
# ['～得）', '～得', '～得～）', '我～唔']
# ['出～。']
# ['牙～。']
# ['～']
# ['電視～着｜', '燈冇～了。']
# ['～屄(']
# ['～）']
# ['～埋']
# ['～棉', '～豆']
# ['～隻']
# ['你咪～｜', '～下']
# ['怩怩～～）', '怩～～）', '論日～。']
# ['飢～～）', '飢～～）']
# ['木瓜～。']
# ['木～b', '金～唔b']
# ['心～。']
# ['～成', '～腳', '～水；', '～～', '～～縮']
# ['～高']
# ['你～起']
# ['～本']
# ['～）', '～）']
# ['好～冇']
# ['屎～）']
# ['食～米。']
# ['開～褲。']
# ['鼻～。']
# ['落～）']
# ['～嘴）']
# ['頭鞋～窄。']
# ['到人～人。']
# ['～手', '～身｜', '～衫']
# ['～死；', '筷子～來', '～來～去｜', '～肉']
# ['人']
# ['煮～飯。']
# ['～黑；', '煮～飯；', '花都～晒。']
# ['細～｜', '～兒｜', '兒～｜', '～仔(']
# ['臭']
# ['两個～；', '傻～｜', '乖～。']
# ['蚊']
# ['葉好～｜', '～粒', '仲好～｜', '～粒']
# ['～氣｜', '打～。']
# ['你～個', '路去～幾']
# ['佢好～個，', '真係～；', '佢～彈']
# ['～細']
# ['黃～魚）']
# ['～佬。']
# ['～！', '～多']
# ['坐～。']
# ['～好', '～啲', '～名；', '立亂～｜', '自己～出']
# ['～娺）', '肥屍～。']
# ['湯～耐', '腐～）']
# ['～唔']
# ['將軍']
# ['狗']
# ['戆個']
# ['樹～）']
# ['～死｜', '～醜；', '恐～｜', '～你']
# ['～着']
# ['我就～掣']
# ['～到', '～財']
# ['～船｜', '～車。']
# ['臭～～）', '臭～～）']
# ['～幾']
# ['飯～。']
# ['攞棍～䘃', '水中～ ', '兩～。']
# ['～蛋）']
# ['～']
# ['尿～；', '卵～）']
# ['算埋～，']
# ['譇大']
# ['～走。']
# ['綠豆']
# ['螺絲～。']
# ['～果｜', '～']
# ['俾我～']
# ['～']
# ['～來', '～來～去；', '～蹸）', '乜咁～｜', '事好～。']
# ['大～）']
# ['一～工｜', '一～垃']
# ['鬆～～；', '鬆～～；', '～腩）']
# ['～一', '～開']
# ['打～。']
# ['癫～。']
# ['要就～唨']
# ['得咁～，', '安咁～。']
# ['常挨～；', '～酒）', '～友）']
# ['～甩']
# ['～下']
# ['～頭', '～孖']
# ['～骨｜', '唔怕～斷。']
# ['椅～｜', '挨～｜', '牀～。']
# ['椅～｜', '挨～｜', '牀～。']
# ['瓦～）']
# ['敲～～；', '敲～～；', '～～）', '～～）']
# ['～嘢。']
# ['～～）', '～～）', '我～好']
# ['一～泥']
# ['白～～）', '白～～）']
# ['～s']
# ['～鼠）']
# ['幾～嘢。']
# ['螃～）']
# ['～袋(']
# ['～一', '～一～。']
# ['下你～面；', '～下']
# ['一～｜', '有～。']
# ['～雨｜', '捱雨～湿']
# ['～']
# ['～開；', '～取；', '～水｜', '～水']
# ['一～']
# ['一～羅）']
# ['識～你；', '～開']
# ['磚～）']
# ['生～）']
# ['～來', '～來～去，', '頻～。']
# ['～烂）']
# ['海～）', '地城～。']
# ['～高']
# ['粥～出']
# ['～定(']
# ['～相(']
# ['打一～麻']
# ['～口']
# ['～蘆）', '～瓜。']
# ['～頭｜', '～面(']
# ['新～）']
# ['～佢']
# ['～街｜', '～檯。']
# ['～死；', '～財。']
# ['檯～。']
# ['～上']
# ['～烴']
# ['～']
# ['一～']
# ['邊隻～裏']
# ['～紙）']
# ['年～']
# ['～冧）', '～！']
# ['麻麻～～）', '麻～～）']
# ['～）']
# ['一～']
# ['～檔(', '論日～我']
# ['多謝～！', '做～嘢']
# ['～亡；']
# ['软～～｜', '软～～｜', '腰骨～～。', '骨～～。']
# ['～;', '～h']
# ['手～）']
# ['～']
# ['老板～。']
# ['～～）', '～～）']
# ['～手｜', '～尿；', '我嚇～跳', '～醒；', '米～得 ', '～架(']
# ['一眼～過', '～來', '～來～去。']
# ['走～～）', '走～～）']
# ['着狗～了']
# ['佢～得']
# ['～g']
# ['孫孫～～。', '孫～～。']
# ['醒～）']
# ['跳～～）', '跳～～）']
# ['聽佢～｜', '係度～你']
# ['你咁～，']
# ['打～忍）']
# ['笑～～｜', '笑～～｜', '懵～～｜', '懵～～｜', '戇～～。', '戇～～。']
# ['绫～）']
# ['～s', '葛好～。']
# ['抖～｜', '隻腳～來', '～來～去，']
# ['打～豉', '冇整～。']
# ['～｜', '～～；', '～～；']
# ['冇佢～住']
# ['～l']
# ['儆～；']
# ['～啲']
# ['心～；']
# ['發～。']
# ['香～）']
# ['門～；', '～']
# ['啲嘢～落']
# ['～到']
# ['白～～）', '白～～）']
# ['菩萨～）']
# ['白～～）', '白～～）']
# ['聲～）']
# ['～把']
# ['～）']
# ['啲去～；', '～大']
# ['～～', '～～滾）', '～l']
# ['食完～乾']
# ['白～～）', '白～～）']
# ['～食｜', '～飯。']
# ['開兩～；', '啊～埞']
# ['着佢～了']
# ['眼啲～落']
# ['肋～骨）', '～條）']
# ['唥～｜', '～包(']
# ['嘴～；', '眼～。']
# ['～門｜', '～窗。']
# ['就被～去']
# ['～稠']
# ['～镬；', '老闆～。']
# ['～腎。']
# ['～水｜', '～氣。']
# ['～氣）']
# ['～食；', '～你；', '～喉）']
# ['～爲(', '弊～。']
# ['～箕；', '水～。']
# ['一槌～过']
# ['～牙｜', '牙～～。', '牙～～。']
# ['一脚～過', '～齊']
# ['～米。']
# ['～力｜', '～嘢；', '經常～我', '唔～落', '～錢｜', '～好']
# ['～牛｜', '～牛']
# ['得夠～；', '題好～｜', '～筆']
# ['日好～啊｜', '玩～唔', '～唔～，', '鼎好～，']
# ['你～下', '～妹']
# ['～聲）', '成日～佢']
# ['肉～｜', '米～。']
# ['～浡', '豬～|', '擔～。']
# ['慳～｜', '～衰(']
# ['頭～｜', '～乸。']
# ['紮咁～我', '密～。', '睺～佢。']
# ['啲飯～嚟']
# ['～起', '～盲']
# ['～九']
# ['嫖～。']
# ['懶又～｜', '死～爛', '～王(', '生～。']
# ['幾十～你', '嗱嗱～｜', '好好～。']
# ['～衫。']
# ['天～～；', '天～～；', '～爧｜', '天～。']
# ['～本；', '製膠～矣｜', '底都～矣。']
# ['佢好～。']
# ['～油）']
# ['鼻～）']
# ['～得', '得唔～得；', '～做(', '～英']
# ['～佢']
# ['你在～啲？']
# ['人～畀', '馬～畀']
# ['識幾～。']
# ['～日。']
# ['冇～”', '識冇～，']
# ['渠～叻', '～有）']
# ['～石；', '～起']
# ['～～d', '～～d']
# ['一～芭']
# ['做']
# ['啲嘢～近；', '～把']
# ['尿時～一']
# ['～吃｜', '～鬼', '嘴咁～噶？']
# ['～～', '～～先；']
# ['牙～）']
# ['我～撴', '我～！']
# ['～米(']
# ['啲木～到']
# ['你都～嘅']
# ['～佢']
# ['～球。']
# ['筷子～佢。']
# ['敲～｜', '睇～｜', '～頭；', '睇你～。']
# ['～飯；', '揾']
# ['～走']
# ['邊']
# ['蠄～）']
# ['佢～到']
# ['～縮）', '～～', '～～縮']
# ['心～～。', '心～～。']
# ['～～', '～～然）', '先至～噉']
# ['～正）']
# ['落']
# ['佢冇～？']
# ['頭～）', '行～）', '最整～嘅', '我誃～｜', '誃頭～。']
# ['～雞。']
# ['～）', '～）']
# ['係佢～嘅。']
# ['你～住', '～水。']
# ['～目｜', '～水。']
# ['抓還～。']
# ['刀生～喇。']
# ['～～', '～～噉']
# ['～']
# ['～一']
# ['～完']
# ['～澌', '～滑']
# ['肚好～｜', '酸嘢～肚；', '藥好～。']
# ['肉好～。']
# ['～睇(']
# ['～牙；', '酒瓶～爆']
# ['～）']
# ['喺度～我；', '佢～我']
# ['～鹽。']
# ['又冇～我。']
# ['～我']
# ['戇～。']
# ['屙～。']
# ['～溦）', '哭～～）', '哭～～）']
# ['順～；', '～顧）']
# ['插～）']
# ['人哋～都', '都冇～你；', '～顧。']
# ['～口']
# ['冇整～火']
# ['臭']
# ['～包）', '包～）', '～米）']
# ['～灯；', '心～）']
# ['日日～～', '日～～停']
# ['冇過～）', '翻～）']
# ['隻手～唨。']
# ['～子']
# ['車～｜', '爆～。']
# ['領～。']
# ['～茶｜', '～世', '～空']
# ['～尾。']
# ['情情～ ', '～）']
# ['屎～｜', '埕埕～～。', '埕～～。']
# ['又被～唨']
# ['～下']
# ['滑～～；', '滑～～；', '～手）']
# ['～煲。']
# ['～書；', '試㧬～下']
# ['～杯']
# ['～妹']
# ['～衫', '～衫～']
# ['我好～｜', '～雞(', '手～脚']
# ['一腳～渠', '～開5']
# ['食过～噶。']
# ['記得～好']
# ['～～', '～～扂）']
# ['警察～唨', '老師～唨']
# ['～氣；', '～下', '早～）']
# ['～火(']
# ['～來', '～來～去｜', '～上', '～上～落。']
# ['肥～～）', '肥～～）']
# ['～水。']
# ['～勾。']
# ['～手', '～土']
# ['～日）']
# ['一～啤']
# ['～任；', '～佢']
# ['車太～；', '～回', '～錢）']
# ['～棍；', '～友；', '一～題；', '一～數(', '～']
# ['～痰。']
# ['我仲～住']
# ['～被。']
# ['～起', '～上', '一隻～；', '一～糖。']
# ['～落']
# ['～頹）']
# ['～～', '～～']
# ['～仔｜', '澳～大']
# ['～雞；', '～西']
# ['～㩡｜', '～']
# ['～平']
# ['上～｜', '英文～。']
# ['一～被｜', '一～蚊']
# ['麻～雞']
# ['批～）']
# ['記得～筆', '水管～起', '東～西', '～西～就', '～門｜', '～車。']
# ['一～學', '一～鴨｜', '一～馬。']
# ['～佬｜', '你咁～嗰？']
# ['～骨）']
# ['～下']
# ['細最～你', '好～）', '幾好～哦！']
# ['我～你', '～佢', '～我']
# ['老婆～渠']
# ['新～｜', '返～｜', '～企｜', '～']
# ['～啲']
# ['～佢']
# ['～a']
# ['米～｜', '～缸。']
# ['～菜）']
# ['～鬼）', '啲～去']
# ['～人）']
# ['冇系～？']
# ['～名）', '路哥～十', '佢～係']
# ['就～）', '趕就～嗟。']
# ['～～', '～～拐']
# ['～被）']
# ['～車｜', '～船。']
# ['～～', '～～西', '～金', '～～', '～～手']
# ['上～｜', '四～九']
# ['土瓜～｜', '沙～｜', '南～｜', '西～。']
# ['一人～一', '路～路，', '數～數。']
# ['車輪～嘞；', '佢搞～嘞。']
# ['～出', '～銀；', '佢～穿']
# ['～']
# ['睇下～！', '係～！']
# ['生得～；']
# ['～衫｜', '屋幾～喎｜', '～出']
# ['難～）', '真係～你']
# ['難～）', '事仲～你']
# ['關落']
# ['有～｜', '嗎～。']
# ['羅沖～｜', '君珠～。']
# ['～田）']
# ['～意）', '冇～']
# ['～過）', '～到）', '～止）', '～十', '～得', '都算～。']
# ['～食）']
# ['粉整～張']
# ['～']
# ['發～；', '～雞。']
# ['～陣）', '攞～｜', '聲佢～啲。']
# ['腳～；']
# ['警察～賊']
# ['過三～南']
# ['魚～）']
# ['～陀']
# ['你～轉']
# ['～力。']
# ['～～）', '～～）', '～～', '～～雷', '耳都～。']
# ['～）']
# ['～機｜', '～']
# ['～林｜', '～南；', '屋好～｜', '～窒(']
# ['門窗～蚊']
# ['～手', '～到', '～頭']
# ['桃～；', '～突）']
# ['～角｜', '～低']
# ['醜～～）', '醜～～）']
# ['～～', '～～腍']
# ['睇下～！', '係～！']
# ['我好～你']
# ['算嘹～；', '北海～；', '就食～。']
# ['亂畫']
# ['去嘞～？', '博士～，', '噉做～。']
# ['割～。']
# ['～蓋｜', '～']
# ['唔使～。']
# ['街好～；', '鋪好～；', '雀好～。']
# ['蚊子～熟']
# ['～番', '～']
# ['雞～｜', '～梢。']
# ['～承）', '嘢我～唨']
# ['～一', '～痛｜', '～聲(']
# ['～開；', '走～）']
# ['～到']
# ['～｜', '～兒；', '男～｜', '女～；', '凳～｜', '碗～；', '陳～。']
# ['咁～）', '做完～；', '得～）', '紅～。']
# ['～計）']
# ['～面｜', '～邊。']
# ['～下', '～毣；', '～～）', '～～）', '～毣\u200b', '袋米～有', '～稱']
# ['～茶｜', '～水；', '水～街｜', '捱水～。']
# ['卅幾～咁', '有一～油；']
# ['～）']
# ['人所～魚']
# ['乞人～｜', '我好～佢。']
# ['䒐～）']
# ['啲菜～下']
# ['～）']
# ['～落', '～之）', '佢哋～在']
# ['木～｜', '樽～。']
# ['挨佢～。']
# ['蜘～）']
# ['～l']
# ['～）']
# ['蟬～。']
# ['香～；', '～淚；', '～丟']
# ['花都～澌', '個人～唨。']
# ['～來', '～來～去。']
# ['金～。']
# ['～錢。']
# ['～你。']
# ['小～。']
# ['溼～～。', '溼～～。']
# ['等我～咗']
# ['老～|', '公～|', '姨～｜', '舅公']
# ['～錢｜', '～車(']
# ['好多～；', '多啲～；', '葛好～；', '癩～）']
# ['鹹菜～、', '酸菜～；', '用鹽～做', '酸菜～就']
# ['～嘢；', '得咁～㗎│', '葉好～，']
# ['～）']
# ['上會～崩']
# ['～死｜', '～嬌；']
# ['藞～）']
# ['一～花', '一～米。']
# ['～厊）', '～']
# ['～沙']
# ['䊆石～住', '大石～死']
# ['房好～；', '褲太～，']
# ['～']
# ['～得”', '～得']
# ['脚～']
# ['肚']
# ['～馬', '雀仔～在', '蒼蠅～在']
# ['大廳～開']
# ['～刀）', '～草。']
# ['～～', '～～跳）']
# ['～職；', '～數(', '～記(']
# ['～水｜', '～旱。']
# ['～實']
# ['雞～；', '我～你；', '～數。']
# ['大～）']
# ['～低', '～埋(']
# ['冇人～得']
# ['唔～就', '事唔～得']
# ['發～）']
# ['剎～｜', '撳～。']
# ['仔食～咗，']
# ['～胃）']
# ['溼～）', '有啲～。']
# ['～板。']
# ['～茶；', '今晚～直']
# ['～定', '～住']
# ['一～']
# ['～蛴(']
# ['～豬', '～錢；', '～死。']
# ['影得～|', '睇冇～。']
# ['隻包～係']
# ['手～｜', '腳']
# ['等～｜', '一～間；', '去嗰～記']
# ['～淨', '～行', '～毛', '～垃', '我又～返', '你～到', '我冇～得', '～橘']
# ['錙～）']
# ['～到', '～渠']
# ['鬱～；', '～住']
# ['想上～你']
# ['得帶～。']
# ['佢～是']
# ['嘢好～。']
# ['～了，']
# ['水']
# ['遴～。']
# ['人哋～我。']
# ['吱～。']
# ['～錢｜', '～工']
# ['～佢', '猛～走｜', '亂～食。']
# ['三點～｜', '林街～｜', '扯斷～。']
# ['～少；', '～多）']
# ['～在）', '～得', '～當']
# ['～過）', '我～整。']
# ['～程）', '～就']
# ['一張']
# ['～車｜', '～菜；', '捱人']
# ['作業～得', '等下～。']
# ['～早；', '今～；', '食～。']
# ['～埞｜', '輪車～齊', '冇～我', '佢～矣']
# ['米～｜', '衍子～｜', '糖～｜', '糖隆']
# ['～衫。']
# ['～燈；', '～電', '～車；', '～數）', '有乜～啊；', '～數）', '幾～喎；', '～味；', '～雷', '我～拉', '父母～送']
# ['頭起～。']
# ['～實']
# ['雞尾～。']
# ['蜜蜂～。']
# ['樹枝～落', '太重～斷']
# ['婠～）']
# ['吱啊～。']
# ['河～石', '～水。']
# ['～筆｜', '～筷']
# ['心～）']
# ['～落']
# ['～落', '～頭']
# ['路一～一', '～一～。']
# ['兩家～一']
# ['～有', '～會']
# ['用火～下｜', '～火(']
# ['横一～是']
# ['得咁～！']
# ['筷～｜', '～籠；', '夾一～菜。']
# ['～奶│', '～田', '對鞋～住']
# ['～茶', '～屎']
# ['～縶）']
# ['～z']
# ['打～）']
# ['～高；', '～款；', '床～。']
# ['湯水～口']
# ['～～。', '～～。']
# ['一～口', '一～黐', '一～牙']
# ['～）']
# ['由～）', '冇去～你。']
# ['～故']
# ['喺度～。']
# ['～條']
# ['～']
# ['己亂～上', '就亂～一']
# ['魚～｜', '蝦～。']
# ['～）', '～都']
# ['爛']
# ['～工；', '～人；', '～冇', '～冇～；', '報告～了', '行～去', '蒸～嘅', '我啱～過']
# ['～z']
# ['挨～住', '袖挨～']
# ['～血(']
# ['游水～着｜', '飲水～']
# ['論日～佢。']
# ['係一～兩', '～兩～嘹；', '尖沙～｜', '大角～。']
# ['～管）', '你～去，']
